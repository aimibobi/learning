# %%
import pandas as pd
import numpy as np
hb = pd.DataFrame(pd.read_csv('湖经社区人员信息汇总.csv'))

# %%
hb.head()
# Out:
#    序号   姓名 性别   现住详细地址   备注
# 0   1  秦祖扬  男  2-2-301  NaN
# 1   2  颜毅滨  女  2-2-301  NaN
# 2   3   朱红  女  3-2-202  NaN
# 3   4   申杰  男  3-2-202  NaN
# 4   5  申虹雯  女  3-2-202  NaN

# %%
hb.to_csv('湖经社区人员信息汇总.csv',index=False,encoding='utf-8')

# %%
hb[1][姓名]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-e2dd122d5807> in <module>
# ----> 1 hb[1][姓名]
#
# ...

# %%
l了·flag
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4482    False
# 4483    False
# 4484    False
# 4485    False
# 4486    False
# Length: 4487, dtype: bool

# %%
dup = hbueman.duplicated(subset='序号')
dup = dup[dup]
print (hbueman.iloc[dup.index])
# Out:
#         序号   姓名 性别        现住详细地址           备注
# 952    953   刘利  女         群贤楼一楼  nan/nan/nan
# 54      55  顾柳依  女           NaN          NaN
# 51      52  谢培英  女           NaN          NaN
# 55      56  王珍义  女      12-2-501          NaN
# 52      53  刘珊珊  女           NaN          NaN
# ...    ...  ... ..           ...          ...
# 2985  2049   李敏  女  法商公租房4-1-302          NaN
# 950    951  杨建华  女    汀兰苑33—1202  nan/nan/nan
# 3584  1750  谭志国  男    汀兰苑6-1-101          NaN
# 951    952  刘道均  男        湖北经济学院  nan/nan/nan
# 2986  2050   段莹  女    汀兰苑A1-1902          NaN
#
# [1838 rows x 5 columns]

# %%
hbueman = hbueman.sort_values(by='序号',ascending=False)

# %%
hbueman = hbueman.drop_duplicates(subset='序号',keep='first')

# %%
hbueman.shape
# Out:
# (2649, 5)

# %%
hbueman.to_csv('hbueman.csv', index=False, sep=',')

# %%
hbueman.sort_values(by='姓名')
# Out:
#         序号                                       姓名   性别    现住详细地址  \
# 88    2561                  ANNANG JONATHAN ADJA 安南    男   桂苑1栋1单元
# 67    2582                 ASONGNA ERNEST MBECHO 宋北    男   桂苑1栋1单元
# 389   2260                 ASONGNA ERNEST MBECHO 宋北    男   桂苑1栋1单元
# 77    2572  BASSOM BASSOM CHRISTOPHE HAIMMANOT  克力思    男   桂苑1栋1单元
# 78    2571       BASSOM BASSOM JORDAN AKHENATON  乔丹    男   桂苑1栋1单元
# ...    ...                                      ...  ...       ...
# 1304  1345                                      NaN  NaN       NaN
# 1305  1344                                      NaN  NaN       NaN
# 1309  1340                                      NaN  NaN       NaN
# 2398   251                                      NaN    男   A2-1802
# 2511   138                                      NaN    男  28-2-201
#
#                                     备注
# 88                                 NaN
# 67                                 NaN
# 389   0442978/87990507/18186112129/喀麦隆
# ...

# %%
hbueman.to_excel('hbueman.xls')

# %%
hbueman.isna
# Out:
# <bound method DataFrame.isna of         序号   姓名 性别       现住详细地址   备注
# 0     2649  张黎明  女   汀兰苑9—2—102  NaN
# 1     2648   包蕾  女   32--1--102  NaN
# 2     2647   张力  男       33栋5O1  NaN
# 3     2646  伍艮香  女  订兰苑小区33栋501  NaN
# 4     2645   汪梦  女  公租房2栋四单元302  NaN
# ...    ...  ... ..          ...  ...
# 2644     5  申虹雯  女          NaN  NaN
# 2645     4   申杰  男          NaN  NaN
# 2646     3   朱红  女      3-2-202  NaN
# 2647     2  颜毅滨  女          NaN  NaN
# 2648     1  秦祖扬  男      2-2-301  NaN
#
# [2649 rows x 5 columns]>

# %%
hbueman=hbueman.dropna(thresh=4)

# %%
hbueman.dtypes
# Out:
# 序号         int64
# 姓名        object
# 性别        object
# 现住详细地址    object
# 备注        object
# dtype: object

# %%
hbueman.drop_duplicates(subset=['姓名','性别','现住详细地址','备注'],keep='first')
# Out:
#         序号   姓名 性别       现住详细地址   备注
# 0     2649  张黎明  女   汀兰苑9—2—102  NaN
# 1     2648   包蕾  女   32--1--102  NaN
# 2     2647   张力  男       33栋5O1  NaN
# 3     2646  伍艮香  女  订兰苑小区33栋501  NaN
# 4     2645   汪梦  女  公租房2栋四单元302  NaN
# ...    ...  ... ..          ...  ...
# 2637    12  姚玉霞  女      5-2-301  NaN
# 2639    10   万山  男      4-2-301  NaN
# 2643     6  李义敏  男      3-2-302  NaN
# 2646     3   朱红  女      3-2-202  NaN
# 2648     1  秦祖扬  男      2-2-301  NaN
#
# [2234 rows x 5 columns]

# %%
hbueman=hbueman.sort_values(by='序号',=Trascendingue)

# %%
hbueman.set_index(['序号'])
# Out:
#        姓名 性别       现住详细地址   备注
# 序号
# 2649  张黎明  女   汀兰苑9—2—102  NaN
# 2648   包蕾  女   32--1--102  NaN
# 2647   张力  男       33栋5O1  NaN
# 2646  伍艮香  女  订兰苑小区33栋501  NaN
# 2645   汪梦  女  公租房2栋四单元302  NaN
# ...   ... ..          ...  ...
# 5     申虹雯  女          NaN  NaN
# 4      申杰  男          NaN  NaN
# 3      朱红  女      3-2-202  NaN
# 2     颜毅滨  女          NaN  NaN
# 1     秦祖扬  男      2-2-301  NaN
#
# [2649 rows x 4 columns]

# %%
hbueman.to_excel('hbueman.xls')

# %%
hbueman.head()
# Out:
#       序号   姓名 性别   现住详细地址   备注
# 2648   1  秦祖扬  男  2-2-301  NaN
# 2647   2  颜毅滨  女      NaN  NaN
# 2646   3   朱红  女  3-2-202  NaN
# 2645   4   申杰  男      NaN  NaN
# 2644   5  申虹雯  女      NaN  NaN

# %%
hbueman.shape
# Out:
# (2649, 5)

# %%
hbueman = hbueman.drop_duplicates(subset=['姓名','性别','现住详细地址','备注'],keep='first')

# %%
hbueman.dtypes
# Out:
# 序号         int64
# 姓名        object
# 性别        object
# 现住详细地址    object
# 备注        object
# dtype: object

# %%
hbueman.head()
# Out:
#       序号   姓名 性别   现住详细地址   备注
# 2648   1  秦祖扬  男  2-2-301  NaN
# 2647   2  颜毅滨  女      NaN  NaN
# 2646   3   朱红  女  3-2-202  NaN
# 2645   4   申杰  男      NaN  NaN
# 2644   5  申虹雯  女      NaN  NaN

# %%
hbueman.shape
# Out:
# (2463, 5)

# %%
hbueman.to_excel('hbueman.xls')

# %%
#df4 = df4.dropna(subset=["age", "sex"]) 删除age,sex列空数据的行

# %%
hbueman = pd.DataFrame(pd.read_excel('hbueman.xls'))

# %%
fr = pd.DataFrame(pd.read_excel('fr.xlsx'))

# %%
hbueman.head()
# Out:
#    序号   姓名 性别   现住详细地址   备注
# 0   1  秦祖扬  男  2-2-301  NaN
# 1   2  颜毅滨  女      NaN  NaN
# 2   3   朱红  女  3-2-202  NaN
# 3   4   申杰  男      NaN  NaN
# 4   5  申虹雯  女      NaN  NaN

# %%
del fr['Unnamed: 5']

# %%
fr.head()
# Out:
#      序号                             姓名 性别   现住详细地址            备注
# 0  2238  NYAKABWE CHARMAINE RUTENDO 麦妮  女  桂苑1栋1单元  GN021716津巴布韦
# 1  2239        ANNANG JONATHAN ADJA 安南  男  桂苑1栋1单元    G0950348加纳
# 2  2240              TEMBO CHIPAZYO 邓博  男  桂苑1栋1单元   ZN399180赞比亚
# 3  2241               KABANO SAMUEL 撒卡  男  桂苑1栋1单元   PC255025卢旺达
# 4  2242                  MAFU FIONA 费美  女  桂苑1栋1单元   A03439580南非

# %%
fr['备注'] = fr['备注'].map(str)+fr['Unnamed: 6'].map(str)

# %%
fr.head()
# Out:
#      序号                             姓名 性别   现住详细地址            备注 Unnamed: 6  \
# 0  2238  NYAKABWE CHARMAINE RUTENDO 麦妮  女  桂苑1栋1单元  GN021716津巴布韦       津巴布韦
# 1  2239        ANNANG JONATHAN ADJA 安南  男  桂苑1栋1单元    G0950348加纳         加纳
# 2  2240              TEMBO CHIPAZYO 邓博  男  桂苑1栋1单元   ZN399180赞比亚        赞比亚
# 3  2241               KABANO SAMUEL 撒卡  男  桂苑1栋1单元   PC255025卢旺达        卢旺达
# 4  2242                  MAFU FIONA 费美  女  桂苑1栋1单元   A03439580南非         南非
#
#               备
# 0  GN021716津巴布韦
# 1    G0950348加纳
# 2   ZN399180赞比亚
# 3   PC255025卢旺达
# 4   A03439580南非

# %%
del fr['Unnamed: 6']

# %%
del fr['备']

# %%
fr.head()
# Out:
#      序号                             姓名 性别   现住详细地址            备注
# 0  2238  NYAKABWE CHARMAINE RUTENDO 麦妮  女  桂苑1栋1单元  GN021716津巴布韦
# 1  2239        ANNANG JONATHAN ADJA 安南  男  桂苑1栋1单元    G0950348加纳
# 2  2240              TEMBO CHIPAZYO 邓博  男  桂苑1栋1单元   ZN399180赞比亚
# 3  2241               KABANO SAMUEL 撒卡  男  桂苑1栋1单元   PC255025卢旺达
# 4  2242                  MAFU FIONA 费美  女  桂苑1栋1单元   A03439580南非

# %%
fr.set_index(['序号'])
# Out:
#                                            姓名 性别         现住详细地址  \
# 序号
# 2238            NYAKABWE CHARMAINE RUTENDO 麦妮  女        桂苑1栋1单元
# 2239                  ANNANG JONATHAN ADJA 安南  男        桂苑1栋1单元
# 2240                        TEMBO CHIPAZYO 邓博  男        桂苑1栋1单元
# 2241                         KABANO SAMUEL 撒卡  男        桂苑1栋1单元
# 2242                            MAFU FIONA 费美  女        桂苑1栋1单元
# 2243                 SHAH MANAHIL FATIMAH 马娜娜  女        桂苑1栋1单元
# 2244          KYATWA ESTOMICHI-DOMINUS T M 王子  男        桂苑1栋1单元
# 2245                        MVULA SANGWANI 宋万  男        桂苑1栋1单元
# 2246                DONATO ANGEL ABOGO ADA 安黑  男        桂苑1栋1单元
# 2247                      KAYEMBE FORTUNE 富丽丽  女        桂苑1栋1单元
# 2248     NHANTUMBO MARCO EUSÉBIO DE AMARAL 马可  男        桂苑1栋1单元
# 2249       BASSOM BASSOM JORDAN AKHENATON  乔丹  男        桂苑1栋1单元
# 2250  BASSOM BASSOM CHRISTOPHE HAIMMANOT  克力思  男        桂苑1栋1单元
# 2251                 KALAMA HOPESON STYTER 马卡  男        桂苑1栋1单元
# ...

# %%
hbueman.set_index(['序号'])
# Out:
#        姓名 性别       现住详细地址   备注
# 序号
# 1     秦祖扬  男      2-2-301  NaN
# 2     颜毅滨  女          NaN  NaN
# 3      朱红  女      3-2-202  NaN
# 4      申杰  男          NaN  NaN
# 5     申虹雯  女          NaN  NaN
# ...   ... ..          ...  ...
# 2645   汪梦  女  公租房2栋四单元302  NaN
# 2646  伍艮香  女  订兰苑小区33栋501  NaN
# 2647   张力  男       33栋5O1  NaN
# 2648   包蕾  女   32--1--102  NaN
# 2649  张黎明  女   汀兰苑9—2—102  NaN
#
# [2463 rows x 4 columns]

# %%
result = pd.merge(hbueman,fr,on='序号')

# %%
fr.to_excel('fr.xlsx')

# %%
result.head()
# Out:
#      序号 姓名_x 性别_x        现住详细地址_x 备注_x                           姓名_y 性别_y  \
# 0  2238  胡春霞    女  江夏区藏龙岛杨桥湖大道13号  NaN  NYAKABWE CHARMAINE RUTENDO 麦妮    女
# 1  2239  杨爱珍    女     汀兰苑20－2－302  NaN        ANNANG JONATHAN ADJA 安南    男
# 2  2240  刘沛蓬    男          员工楼612  NaN              TEMBO CHIPAZYO 邓博    男
# 3  2241   郭恺    男  中百罗森后面一栋楼9012号  NaN               KABANO SAMUEL 撒卡    男
# 4  2243  吕学云    女         2-2-201  NaN       SHAH MANAHIL FATIMAH 马娜娜    女
#
#   现住详细地址_y           备注_y
# 0  桂苑1栋1单元   GN021716津巴布韦
# 1  桂苑1栋1单元     G0950348加纳
# 2  桂苑1栋1单元    ZN399180赞比亚
# 3  桂苑1栋1单元    PC255025卢旺达
# 4  桂苑1栋1单元  ML5148903巴基斯坦

# %%
hbueren = hbueman.append(fr)

# %%
hbueren.to_excel('hbueren.xls')

# %%
hbueman = pd.DataFrame(pd.read_excel('hbueman.xls'))
fr = pd.DataFrame(pd.read_excel('fr.xlsx'))

# %%
result = pd.merge(hbueman,fr.loc[:,['姓名','备注']],how='left',on = '姓名')#向hbueman添加fr的备注列

# %%
result.to_excel('hbueren.xls')

# %%
fr.head()
# Out:
#      序号                             姓名 性别   现住详细地址            备注
# 0  2238  NYAKABWE CHARMAINE RUTENDO 麦妮  女  桂苑1栋1单元  GN021716津巴布韦
# 1  2239        ANNANG JONATHAN ADJA 安南  男  桂苑1栋1单元    G0950348加纳
# 2  2240              TEMBO CHIPAZYO 邓博  男  桂苑1栋1单元   ZN399180赞比亚
# 3  2241               KABANO SAMUEL 撒卡  男  桂苑1栋1单元   PC255025卢旺达
# 4  2242                  MAFU FIONA 费美  女  桂苑1栋1单元   A03439580南非

# %%
result.head()
# Out:
#    序号   姓名 性别   现住详细地址 备注_x 备注_y
# 0   1  秦祖扬  男  2-2-301  NaN  NaN
# 1   2  颜毅滨  女      NaN  NaN  NaN
# 2   3   朱红  女  3-2-202  NaN  NaN
# 3   4   申杰  男      NaN  NaN  NaN
# 4   5  申虹雯  女      NaN  NaN  NaN
